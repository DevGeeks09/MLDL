# %%
import pandas as pd

# %%
pwd()
# Out:
# 'E:\\Ankita_iNeuron\\class_practice'

# %%
df = pd.read_csv('sample-csv/addresses.csv')

# %%
result ='<table>'

for i in df.columns:
    result = result+'<tr>'+i+'</tr>'
    
for i in df:
    for j in range(len(df[i])):
        display(df.iloc(j))
#display(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\acer\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     545         try:
# --> 546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-e4b45a9de7a7> in <module>
#       6 for i in df:
#       7     for j in range(len(df[i])):
# ----> 8         display(df.iloc(j))
#       9 #display(result)
#
# c:\users\acer\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     635
#     636         if axis is not None:
# --> 637             axis = self.obj._get_axis_number(axis)
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
df.head(2)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US

# %%
df.tail()
# Out:
#     id  location_id                   address_1  address_2  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
df.tail(1)
# Out:
#     id  location_id                   address_1  address_2           city  \
# 20  21           22  2013 Avenue of the fellows  Suite 100  San Francisco
#
#    state_province postal_code country
# 20             CA       94103      US

# %%
pd.read_csv('sample-csv/addresses.csv', header = None)
# Out:
#      0            1                           2          3  \
# 0   id  location_id                   address_1  address_2
# 1    1            1       2600 Middlefield Road        NaN
# 2    2            2            24 Second Avenue        NaN
# 3    3            3            24 Second Avenue        NaN
# 4    4            4            24 Second Avenue        NaN
# 5    5            5            24 Second Avenue        NaN
# 6    6            6           800 Middle Avenue        NaN
# 7    7            7              500 Arbor Road        NaN
# 8    8            8           800 Middle Avenue        NaN
# 9    9            9       2510 Middlefield Road        NaN
# 10  10           10       1044 Middlefield Road        NaN
# 11  11           11         2140 Euclid Avenue.        NaN
# 12  12           12       1044 Middlefield Road  2nd Floor
# 13  13           13         399 Marine Parkway.        NaN
# 14  14           14          660 Veterans Blvd.        NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
df[['location_id','address_1']]
# Out:
#     location_id                   address_1
# 0             1       2600 Middlefield Road
# 1             2            24 Second Avenue
# 2             3            24 Second Avenue
# 3             4            24 Second Avenue
# 4             5            24 Second Avenue
# 5             6           800 Middle Avenue
# 6             7              500 Arbor Road
# 7             8           800 Middle Avenue
# 8             9       2510 Middlefield Road
# 9            10       1044 Middlefield Road
# 10           11         2140 Euclid Avenue.
# 11           12       1044 Middlefield Road
# 12           13         399 Marine Parkway.
# 13           14          660 Veterans Blvd.
# 14           15        1500 Valencia Street
# 15           16         1161 South Bernardo
# 16           17     409 South Spruce Avenue
# 17           18            114 Fifth Avenue
# 18           19         19 West 39th Avenue
# 19           21          123 El Camino Real
# ...

# %%
df['location_id'][0:2]
# Out:
# 0    1
# 1    2
# Name: location_id, dtype: int64

# %%
df[['location_id']][0:2]
# Out:
#    location_id
# 0            1
# 1            2

# %%
df6 = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
df6[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df6[0].head(1)
# Out:
#   Rk      Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT% ORB  DRB  \
# 0  1  Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784  79  222
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
#
# [1 rows x 30 columns]

# %%
df.dtypes
# Out:
# id                 int64
# location_id        int64
# address_1         object
# address_2         object
# city              object
# state_province    object
# postal_code       object
# country           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              21 non-null     int64
#  1   location_id     21 non-null     int64
#  2   address_1       21 non-null     object
#  3   address_2       2 non-null      object
#  4   city            21 non-null     object
#  5   state_province  21 non-null     object
#  6   postal_code     21 non-null     object
#  7   country         21 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 1.4+ KB
